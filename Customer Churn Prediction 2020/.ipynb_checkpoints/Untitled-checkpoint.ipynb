# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
ds = pd.read_csv('train.csv')
ds
# Out:
#      state  account_length      area_code international_plan voice_mail_plan  \
# 0       OH             107  area_code_415                 no             yes
# 1       NJ             137  area_code_415                 no              no
# 2       OH              84  area_code_408                yes              no
# 3       OK              75  area_code_415                yes              no
# 4       MA             121  area_code_510                 no             yes
# ...    ...             ...            ...                ...             ...
# 4245    MT              83  area_code_415                 no              no
# 4246    WV              73  area_code_408                 no              no
# 4247    NC              75  area_code_408                 no              no
# 4248    HI              50  area_code_408                 no             yes
# 4249    VT              86  area_code_415                 no             yes
#
# ...

# %%
train = ds.head(3400).drop(['churn'], axis= 'columns')
train
# Out:
#      state  account_length      area_code international_plan voice_mail_plan  \
# 0       OH             107  area_code_415                 no             yes
# 1       NJ             137  area_code_415                 no              no
# 2       OH              84  area_code_408                yes              no
# 3       OK              75  area_code_415                yes              no
# 4       MA             121  area_code_510                 no             yes
# ...    ...             ...            ...                ...             ...
# 3395    ME             124  area_code_415                 no              no
# 3396    LA             133  area_code_510                 no              no
# 3397    WI              49  area_code_408                 no              no
# 3398    NH             112  area_code_415                 no              no
# 3399    HI             130  area_code_510                 no              no
#
# ...

# %%
target_train = ds.churn.head(3400)
target_train
# Out:
# 0       no
# 1       no
# 2       no
# 3       no
# 4       no
#         ..
# 3395    no
# 3396    no
# 3397    no
# 3398    no
# 3399    no
# Name: churn, Length: 3400, dtype: object

# %%
import seaborn as sns
sns.boxplot(x=train['account_length'])
# Out:
# <AxesSubplot:xlabel='account_length'>

# %%
sns.boxplot(x=train['number_vmail_messages'])
# Out:
# <AxesSubplot:xlabel='number_vmail_messages'>

# %%
sns.boxplot(x=train['total_day_minutes'])
# Out:
# <AxesSubplot:xlabel='total_day_minutes'>

# %%
sns.boxplot(x=train['total_day_calls'])
# Out:
# <AxesSubplot:xlabel='total_day_calls'>

# %%
sns.boxplot(x=train['number_customer_service_calls'])
# Out:
# <AxesSubplot:xlabel='number_customer_service_calls'>

# %%
sns.boxplot(x=train['total_intl_charge'])
# Out:
# <AxesSubplot:xlabel='total_intl_charge'>

# %%
numer = train.drop(['state','area_code','international_plan','voice_mail_plan'],axis='columns')
from sklearn.preprocessing import MinMaxScaler
norm = MinMaxScaler().fit_transform(numer)
cols = numer.columns.values
numeri_normali = pd.DataFrame(data = norm, columns = cols)
numeri_normali.head()
# Out:
#    account_length  number_vmail_messages  total_day_minutes  total_day_calls  \
# 0        0.438017                   0.52           0.459744         0.745455
# 1        0.561983                   0.00           0.692461         0.690909
# 2        0.342975                   0.00           0.851778         0.430303
# 3        0.305785                   0.00           0.474253         0.684848
# 4        0.495868                   0.48           0.620768         0.533333
#
#    total_day_charge  total_eve_minutes  total_eve_calls  total_eve_charge  \
# 0          0.459672           0.556030         0.605882          0.556039
# 1          0.692436           0.344710         0.647059          0.344597
# 2          0.851740           0.176052         0.517647          0.175979
# 3          0.474230           0.421786         0.717647          0.421880
# 4          0.620649           0.991183         0.635294          0.990967
#
# ...

# %%
voci = train.drop(['account_length','number_vmail_messages','total_day_minutes','total_day_calls','total_day_charge','total_eve_minutes','total_eve_calls','total_eve_charge','total_night_minutes','total_night_calls','total_night_charge','total_intl_minutes','total_intl_calls','total_intl_charge','number_customer_service_calls'], axis = 'columns')
from sklearn import preprocessing
from sklearn.preprocessing import OneHotEncoder
enc = OneHotEncoder().fit_transform(voci)
encoded_voice = pd.DataFrame(data=enc, columns=coll)
encoded_voice
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\pandas\core\internals\managers.py in create_block_manager_from_blocks(blocks, axes)
#    1661                 blocks = [
# -> 1662                     make_block(values=blocks[0], placement=slice(0, len(axes[0])))
#    1663                 ]
#
# ~\anaconda3\lib\site-packages\pandas\core\internals\blocks.py in make_block(values, placement, klass, ndim, dtype)
#    2721
# -> 2722     return klass(values, ndim=ndim, placement=placement)
#    2723
#
# ~\anaconda3\lib\site-packages\pandas\core\internals\blocks.py in __init__(self, values, placement, ndim)
#    2377
# -> 2378         super().__init__(values, ndim=ndim, placement=placement)
#    2379
#
# ~\anaconda3\lib\site-packages\pandas\core\internals\blocks.py in __init__(self, values, placement, ndim)
# ...

# %%
voci
# Out:
#      state      area_code international_plan voice_mail_plan
# 0       OH  area_code_415                 no             yes
# 1       NJ  area_code_415                 no              no
# 2       OH  area_code_408                yes              no
# 3       OK  area_code_415                yes              no
# 4       MA  area_code_510                 no             yes
# ...    ...            ...                ...             ...
# 3395    ME  area_code_415                 no              no
# 3396    LA  area_code_510                 no              no
# 3397    WI  area_code_408                 no              no
# 3398    NH  area_code_415                 no              no
# 3399    HI  area_code_510                 no              no
#
# [3400 rows x 4 columns]

# %%
sns.heatmap(ds.corr(),cmap='BuGn');

# %%
ds[ds.select_dtypes(['int64','float64']).columns].boxplot()
plt.xticks(rotation=90);

# %%
voci
# Out:
#      state      area_code international_plan voice_mail_plan
# 0       OH  area_code_415                 no             yes
# 1       NJ  area_code_415                 no              no
# 2       OH  area_code_408                yes              no
# 3       OK  area_code_415                yes              no
# 4       MA  area_code_510                 no             yes
# ...    ...            ...                ...             ...
# 3395    ME  area_code_415                 no              no
# 3396    LA  area_code_510                 no              no
# 3397    WI  area_code_408                 no              no
# 3398    NH  area_code_415                 no              no
# 3399    HI  area_code_510                 no              no
#
# [3400 rows x 4 columns]

# %%
numeri_normali
# Out:
#       account_length  number_vmail_messages  total_day_minutes  \
# 0           0.438017                   0.52           0.459744
# 1           0.561983                   0.00           0.692461
# 2           0.342975                   0.00           0.851778
# 3           0.305785                   0.00           0.474253
# 4           0.495868                   0.48           0.620768
# ...              ...                    ...                ...
# 3395        0.508264                   0.00           0.431294
# 3396        0.545455                   0.00           0.489900
# 3397        0.198347                   0.00           0.742248
# 3398        0.458678                   0.00           0.353912
# 3399        0.533058                   0.00           0.360740
#
#       total_day_calls  total_day_charge  total_eve_minutes  total_eve_calls  \
# 0            0.745455          0.459672           0.556030         0.605882
# ...

# %%
encvoci
# Out:
#       account_length  number_vmail_messages  total_day_minutes  \
# 0           0.438017                   0.52           0.459744
# 1           0.561983                   0.00           0.692461
# 2           0.342975                   0.00           0.851778
# 3           0.305785                   0.00           0.474253
# 4           0.495868                   0.48           0.620768
# ...              ...                    ...                ...
# 3395        0.508264                   0.00           0.431294
# 3396        0.545455                   0.00           0.489900
# 3397        0.198347                   0.00           0.742248
# 3398        0.458678                   0.00           0.353912
# 3399        0.533058                   0.00           0.360740
#
#       total_day_calls  total_day_charge  total_eve_minutes  total_eve_calls  \
# 0            0.745455          0.459672           0.556030         0.605882
# ...
